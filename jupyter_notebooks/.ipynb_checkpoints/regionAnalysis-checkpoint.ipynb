# %% [markdown]
# $$ \LARGE \text{Region Oriented Adoption and Growth Analysis} $$
# ---
#
# ## **`Region Specific Aanlysis`**
# - **Top states**
# - **Emerging districts**
# - **Engagement ratio**
# - **Growth hotspots**

# %% [markdown]
# ## **1️⃣ Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from utils.Graph_Helpers.regionHelper import *

# %% [markdown]
# ## **2️⃣ Global Settings**

# %%
sns.set_style("whitegrid")

plt.rcParams['figure.figsize'] = (14, 7)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## **3️⃣ Load Data**

# %%
PARENT_DIR = "CSVs"
Map_user = pd.read_csv(f"..\\{PARENT_DIR}\\Map_user.csv")

# %% [markdown]
# ## **4️⃣ Small Data preprocessing**

# %%
map_user = handle_missing_app_opens(Map_user)

# %%
plot_top_states(map_user)
# Out:
# D:\Machine_Learning\Internships\labmentix\Project-1 PhonePe Data Analysis\jupyter_notebooks\utils\Graph_Helpers\regionHelper.py:77: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### **`Observation`**
# - **Top 15 state produces higher number of users across all india.**
# ### **`Interpretation`**
# - **India's top 15 states which has more number of registered user in PhonePe.**
# ### **`Business Meaning`**
# - **Top 15 states shows majority PhonePe registered users.**
# - **Shows chances of more adoption and possibly 1% to 2% more growth from these states.**
# ### **`Possible Reasons`**
# - **These top 10 to 15 states are capital / economy driven states in india.**
# - **Each state has major revenue / employment producing startups , ecosystem to increase cash flow, growth and boosting economy.**

# %%
plot_top_districts(map_user)
# Out:
# D:\Machine_Learning\Internships\labmentix\Project-1 PhonePe Data Analysis\jupyter_notebooks\utils\Graph_Helpers\regionHelper.py:136: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### **`Observation`**
# - **Top 15 districts, produces higher number of users across all india.**
# ### **`Interpretation`**
# - **India's top 15 districs which has more number of registered user in PhonePe.**
# ### **`Business Meaning`**
# - **Top 15 districts shows majority PhonePe registered users.**
# - **Shows chances of more adoption and possibility of more growth from here.**
# ### **`Possible Reasons`**
# - **These top districs are capital / economy driven districs.**
# - **Each districts has major much potential in revenue growth and possible higher employment rate.**

# %%
plot_emerging_growth_districts(map_user)

# %% [markdown]
# ### **`Observation`**
# - **Top 10 districs with higher user engagement rate.**
# ### **`Interpretation`**
# - **Even though, there is sudden growth in number of registered users in between 2018 to 2021, user engagement rate is slowly increasing.**
# - **Shows possitive response and stable user adoption.**
# ### **`Business Meaning`**
# - **There is difference between increasing number of registered user and increasing user engagement rate.**
# - **Even though there is sudden spike and decline in number of registered user growth, the user engagement rate is slowly and steadily increasing.**
# ### **`Possible Reasons`**
# - **Since 2018 to 2023, user engagment rate is steadily increasing, shows stable and consistent user adoption.**
# - **After 2023, user engagement rate started suddently increasing shows rapid infrastructure development, stable and faster money flow in economy.**

# %%
plot_engagement_ratio_analysis(map_user)
# Out:
# D:\Machine_Learning\Internships\labmentix\Project-1 PhonePe Data Analysis\jupyter_notebooks\utils\Graph_Helpers\regionHelper.py:301: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### **`Observation`**
# - **Top districs of india shows highest user engagement ratio.**
# ### **`Interpretation`**
# - **India's top districts in which highest number of app users.**
# ### **`Business Meaning`**
# - **Most frequent and constant app users where people are frequently making transactions.**
# ### **`Possible Reasons`**
# - **Districts with higher number of statups, higher employment producing factories has higher user engagement rate, which shows frequent and continues cash flow in economy.**

# %%
plot_state_growth_hotspots(map_user)

# %% [markdown]
# ### **`Observation`**
# -  **Karnataka, Maharashtra, Rajasthan, Telangana, and Gujarat show consistently strong growth in registered PhonePe users from 2018 to 2024. Karnataka appears as the strongest growth hotspot across all years.**
#
# ### **`Interpretation`**
# -  **These states demonstrate faster digital payment adoption and stronger expansion of the PhonePe user ecosystem compared to other regions.**
#
# ### **`Business Meaning`**
# -  **High-growth states indicate mature digital infrastructure, stronger smartphone penetration, and higher dependency on digital payment platforms. These regions can be considered strategic markets for expanding advanced financial services like insurance, lending, and investment products.**
#
# ## **`Possible Reason`**
# -  **Rapid urbanization, better internet connectivity, higher merchant adoption, increasing UPI awareness, and post-pandemic digital payment acceleration may have contributed to stronger growth in these regions.**

# %%
plot_district_growth_hotspots(map_user)
# Out:
# D:\Machine_Learning\Internships\labmentix\Project-1 PhonePe Data Analysis\jupyter_notebooks\utils\Graph_Helpers\regionHelper.py:443: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### **`Observation`**
# - **Northeastern districts such as Senapati, Kamle, and South West Garo Hills show exceptionally high PhonePe user growth rates over time.**
# - **Most top growth hotspot districts belong to digitally emerging and previously underpenetrated regions.**
#
# ### **`Interpretation`**
# - **PhonePe adoption is rapidly expanding in remote and emerging districts, indicating increasing digital payment awareness and usage.**
# - **These regions are transitioning from low digital penetration to active participation in the UPI ecosystem.**
#
# ### **`Business Meaning`**
# - **These districts represent high-potential future markets for PhonePe expansion and financial service adoption.**
# - **Strong growth in underserved regions highlights improving financial inclusion and expanding digital payment reach beyond metro cities.**
#
# ### **`Possible Reasons`**
# - **Improved smartphone penetration, internet connectivity, and UPI awareness may have accelerated adoption in these regions.**
# - **Low initial user bases resulted in very high percentage growth rates over time.**
