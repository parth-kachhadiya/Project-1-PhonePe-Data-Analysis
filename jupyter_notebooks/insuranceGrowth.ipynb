# %% [markdown]
# $$ \LARGE \text{Insurance Growth Analysis} $$
# ---
#
# ## **`Insurance Ecosystem`**
# - **Insurance growth**
# - **Low engagement regions**
# - **Fast growing market**
# - **Behavioural shift**

# %% [markdown]
# ## **1️⃣ Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from utils.Graph_Helpers.insuranceGrowth import *

# %% [markdown]
# ## **2️⃣ Global Settings**

# %%
sns.set_style("whitegrid")

plt.rcParams['figure.figsize'] = (14, 7)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## **3️⃣ Load Data**

# %%
PARENT_DIR = "CSVs"
agg_insurance = pd.read_csv(f"..\\{PARENT_DIR}\\Aggregated_insurance.csv")
map_insurance = pd.read_csv(f"..\\{PARENT_DIR}\\Map_insurance.csv")

# %% [markdown]
# ## **4️⃣ Small Data preprocessing**

# %%
plot_insurance_transaction_growth(agg_insurance)

# %% [markdown]
# ### **`Observation`**
# - **Insurance transaction counts show consistent year-over-year growth across all quarters from 2020 to 2024.**
# - **Quarter 4 consistently records the highest insurance transaction activity compared to other quarters.**
#
# ### **`Interpretation`**
# - **PhonePe insurance adoption is steadily increasing, indicating growing awareness and usage of digital insurance services.**
# - **Higher activity in Quarter 4 suggests seasonal or year-end increases in insurance-related financial planning and purchases.**
#
# ### **`Business Meaning`**
# - **The platform is evolving beyond payments into broader financial service adoption, especially in the insurance ecosystem.**
# - **Strong Q4 performance indicates important seasonal opportunities for insurance campaigns and customer acquisition strategies.**
#
# ### **`Possible Reasons`**
# - **Increasing digital trust, smartphone penetration, and fintech awareness may have accelerated insurance adoption.**
# - **Year-end financial planning, policy renewals, and festive-season financial activity may contribute to stronger Q4 insurance transactions.**

# %%
plot_insurance_amount_growth(agg_insurance)

# %% [markdown]
# ### **`Observation`**
# - **Insurance transaction amounts show strong and continuous growth across all quarters from 2020 to 2024.**
# - **Quarter 4 consistently records the highest insurance transaction value, with a sharp increase after 2021.**
#
# ### **`Interpretation`**
# - **Users are increasingly performing higher-value insurance transactions through PhonePe, indicating growing trust in digital financial services.**
# - **The dominance of Quarter 4 suggests stronger year-end insurance activity and seasonal financial planning behavior.**
#
# ### **`Business Meaning`**
# - **PhonePe is gradually expanding from a payment platform into a broader financial services ecosystem.**
# - **High Q4 insurance transaction values highlight strategic opportunities for targeted insurance campaigns and premium financial products.**
#
# ### **`Possible Reasons`**
# - **Increasing awareness of digital insurance products and improved fintech adoption may have accelerated transaction value growth.**
# - **Year-end policy renewals, tax-saving investments, and festive-season financial activity may contribute to stronger Q4 insurance spending.**

# %%
plot_insurance_atv_analysis(map_insurance)
# Out:
# D:\Machine_Learning\Internships\labmentix\Project-1 PhonePe Data Analysis\jupyter_notebooks\utils\Graph_Helpers\insuranceGrowth.py:198: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### **`Observation`**
# - **Ladakh, Arunachal Pradesh, and Sikkim show the highest average insurance transaction values (ATV) among all states.**
# - **Several northeastern and hilly states consistently appear among the top insurance ATV regions.**
#
# ### **`Interpretation`**
# - **Users in these regions tend to perform fewer but higher-value insurance transactions through PhonePe.**
# - **Higher ATV may indicate stronger adoption of premium insurance products or larger policy-value transactions.**
#
# ### **`Business Meaning`**
# - **These states represent high-value insurance markets with potential for premium financial product expansion.**
# - **Higher insurance ATV suggests growing trust in digital financial services and increasing financial maturity in these regions.**
#
# ### **`Possible Reasons`**
# - **Lower transaction frequency combined with higher policy amounts may naturally increase average transaction values.**
# - **Regional economic behavior, insurance preferences, and growing digital financial awareness may contribute to higher ATV levels.**

# %%
plot_state_insurance_penetration(map_insurance)
# Out:
# D:\Machine_Learning\Internships\labmentix\Project-1 PhonePe Data Analysis\jupyter_notebooks\utils\Graph_Helpers\insuranceGrowth.py:249: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### **`Observation`**
# - **Karnataka, Maharashtra, and Tamil Nadu show the highest insurance transaction activity among all states.**
# - **Southern and economically developed states dominate overall insurance adoption through PhonePe.**
#
# ### **`Interpretation`**
# - **These states demonstrate stronger digital insurance adoption and higher participation in fintech-based financial services.**
# - **Higher transaction activity indicates increasing trust in digital insurance platforms and broader financial ecosystem usage.**
#
# ### **`Business Meaning`**
# - **These regions represent mature insurance markets and strong opportunities for expanding premium financial products.**
# - **High insurance adoption suggests deeper integration of PhonePe into users’ long-term financial activities beyond regular payments.**
#
# ### **`Possible Reasons`**
# - **Better digital infrastructure, higher smartphone penetration, and stronger financial awareness may have accelerated insurance adoption in these states.**
# - **Large urban populations and higher merchant-fintech ecosystems likely contributed to stronger digital insurance activity.**

# %%
plot_district_insurance_penetration(map_insurance)
# Out:
# D:\Machine_Learning\Internships\labmentix\Project-1 PhonePe Data Analysis\jupyter_notebooks\utils\Graph_Helpers\insuranceGrowth.py:300: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### **`Observation`**
# - **Bengaluru Urban district shows significantly higher insurance transaction activity compared to all other districts.**
# - **Most top insurance adoption districts belong to major metropolitan and economically developed urban regions such as Pune, Chennai, Hyderabad, and Gurugram.**
#
# ### **`Interpretation`**
# - **Urban districts demonstrate stronger digital insurance adoption and greater participation in fintech-based financial services.**
# - **Higher insurance transaction activity in metro regions indicates increasing user trust in digital insurance platforms and broader financial awareness.**
#
# ### **`Business Meaning`**
# - **Major urban districts represent mature digital insurance markets with strong potential for premium financial product expansion.**
# - **High adoption in metro districts highlights the importance of urban fintech ecosystems in driving digital financial service growth.**
#
# ### **`Possible Reasons`**
# - **Better internet infrastructure, higher smartphone penetration, and stronger financial literacy may contribute to higher insurance adoption in urban districts.**
# - **Large working populations, higher disposable income, and greater exposure to digital financial services likely accelerated insurance usage in metro regions.**

# %%
plot_hot_quarter_insurance(agg_insurance)

# %% [markdown]
# ### **`Observation`**
# - **Quarter 4 consistently records the highest insurance transaction activity across almost all years.**
# - **Insurance transaction counts show strong year-over-year growth from 2020 to 2024 across every quarter.**
#
# ### **`Interpretation`**
# - **Users are more likely to purchase insurance products during Quarter 4, indicating strong seasonal financial behavior.**
# - **The steady increase across all quarters reflects growing adoption of digital insurance services through PhonePe.**
#
# ### **`Business Meaning`**
# - **Quarter 4 represents the most important business period for insurance-related campaigns, offers, and customer acquisition strategies.**
# - **Increasing insurance activity suggests that PhonePe is expanding beyond payments into broader financial service adoption.**
#
# ### **`Possible Reasons`**
# - **Year-end financial planning, tax-saving investments, and policy renewals may contribute to stronger Q4 insurance activity.**
# - **Growing digital trust, fintech awareness, and post-pandemic digital financial adoption likely accelerated insurance purchases over time.**
