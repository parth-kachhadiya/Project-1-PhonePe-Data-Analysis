# %% [markdown]
# $$ \LARGE \text{Platform Growth Analysis} $$
# ---
#
# ## **`Platform growth`**
# - **User growth**
# - **Transaction growth**
# - **YoY growth**
# - **QoQ growth**

# %% [markdown]
# ## **1️⃣ Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from utils.Graph_Helpers.platformGrowth import *

# %% [markdown]
# ## **2️⃣ Global Settings**

# %%
sns.set_style("whitegrid")

plt.rcParams['figure.figsize'] = (14, 7)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## **3️⃣ Load Data**

# %%
PARENT_DIR = "CSVs"
aggregated_user = pd.read_csv(f"..\\{PARENT_DIR}\\Aggregated_user.csv")
aggregated_transactions = pd.read_csv(f"..\\{PARENT_DIR}\\Aggregated_transaction.csv")

# %% [markdown]
# ## **4️⃣ Small Data preprocessing**

# %%
agg_user = preprocess_data(aggregated_user)
agg_txn = preprocess_data(aggregated_transactions)

# %%
plot_india_user_growth(agg_user)

# %% [markdown]
# ### **`Observation`**
# - **Number of registered PhonePe users between 2018 to 2022 shows, rapid growth and than sudden stability.**
# ### **`Interpretation`**
# - **From 2018 to 2021 is the time where PhonePe shows rapid growth of number of registered users adoption.**
# - **After 2021 the number of users as compare to past becomes stable, the line starts downfall shows mature stability.**
# ### **`Business Meaning`**
# - **The trend line from 2018 to 2021 indicates strong and rapid adoption and trust on PhonePe.**
# - **After 2022, rate of number of users growth become stable shows still new users are switching on it.**
# ### **`Possible Reasons`**
# - **The rapid growth around 2018 to 2022 is pendamic period shows faster adoption of digital payments and trust on PhonePe.**

# %%
plot_top_states_user_growth(agg_user)

# %% [markdown]
# ### **`Observation`**
# - **Similar to previous graph, but top stats in india who has higher number of PhonePe users.**
# ### **`Interpretation`**
# - **Each top state has same pattern in user growth.**
# - **`Pattern-A` : Rapid growth between 2018 to 2021.**
# - **`Pattern-B` : Sudden stability in user growth after 2021, which shows mature market stability.**
# ### **`Business Meaning`**
# - **Top economic driven state started adopting PhonePe for digital transaction in daily life transaction and business transactions also.**
# - **Faster adoption by top economic driven state shows popularity, security, reliability, flexibility and user's trust on PhonePe in digital transactions.**
# ### **`Possible Reasons`**
# - **Top states who contributes in economy more than others like..**
#     - **`Andhra Pradesh` : Most famous cities like vishakhapatnam which is famous for major industrial port and beaches.**
#     - **`Gujarat` : State of business from where major indian businessman from smole to large scale arrived at national level.**
#     - **`Karnataka` : Bengaluru which is indias top IT-Hub.**
# - **Adoption by these states / cities shows that PhonePe is reliable and completely business oriented and stable.**

# %%
plot_transaction_growth(agg_txn)

# %% [markdown]
# ### **`Observation`**
# - **Both graph shows quarter wise transaction count growth in india since 2018 to 2024.**
# ### **`Interpretation`**
# - **In general, all quarters shows healthy transaction growth in 2018 to 2024.**
# - **January to March (quarter-1) is cold time where very low to mid amount of transactions are occurring.**
# - **April to June (quarter-2) and July to September (quarter-3) is warm time where around mid amount of transaction are occuring.**
# - **October to December (quarter-4) is the hottest quarter where majority transactions are occurring.**
# ### **`Business Meaning`**
# - **Business should focus on July to December area where transaction spike starts slowly, in this time business should more focus on providing faster and more secure transaction service.**
# ### **`Possible Reasons`**
# - **Quarter - 4 shows higgest rate of transaction among all because, major indian festivals are in this quarter.**
# - **People starts spending on shopping (E-commerce selling raises), people spends on vactions / short period on holiday.**
# - **People goes theri hometown (Increase in transport).**

# %%
plot_yoy_growth_analysis(agg_user, agg_txn)

# %% [markdown]
# ### **`Observation`**
# - **Year-over-year growth analysis shows the growth in current year as compare to immediate previous year.**
# ### **`Interpretation`**
# - **Since we don't have data before 2018, so technically 2018 would show 100% growth which is wrong. so there is no graph in 2018**
# - **On each year transaction growth is 3X than user growth.**
# - **The peak growth year was 2019, shows pre-pendamic period and peak adoption.**
# - **After 2021, user growth rate start declining but transaction rate is stable, shows adoption in user and trust on system.**
# ### **`Business Meaning`**
# - **Since 2018 to 2021 maximum user started adopting PhonePe as digital transaction medium.**
# - **After 2021, user growth rate became stable (as compare to immediate previous year 2021) but transaction rate is still high, shows registered user has trust on platform.**
# ### **`Possible Reasons`**
# - **The golden period (2018 to 2021) maximum possible people started adopting phonepe, after 2021 people get addicted with the system hence they started using PhonePe in their daily life from small amount to big amount transactions.**

# %%
plot_qoq_user_growth(agg_user)
# Out:
# D:\Machine_Learning\Internships\labmentix\Project-1 PhonePe Data Analysis\jupyter_notebooks\utils\Graph_Helpers\platformGrowth.py:397: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### **`Observation`**
# - **User growth slope on quarterly basis.**
# ### **`Interpretation`**
# - **2018-Q1 to 2012-Q1 is the hottest point where major user joined PhonePe.**
# - **After that, sudden user growth started declining and user growth became stable, shows low to medium amount of users are swithing to PhonePe.**
# ### **`Business Meaning`**
# - **Major users during 2018-Q2 to 2019-Q1 are joined.**
# - **No slwoly, user growth rate is slowing down shows still users are adoping PhonePe.**
# ### **`Possible Reasons`**
# - **Old users are satisfied with service.**
# - **Other users are slowly adopting PhonePe shows possiblities of growth in future.**

# %%
plot_qoq_transaction_growth(agg_txn)
# Out:
# D:\Machine_Learning\Internships\labmentix\Project-1 PhonePe Data Analysis\jupyter_notebooks\utils\Graph_Helpers\platformGrowth.py:447: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### **`Observation`**
# - **Transaction growth slope on quarterly basis.**
# ### **`Interpretation`**
# - **2018-Q1 to 2019-Q4 is the hottest point where major transaction occured via PhonePe platform.**
# - **Q2-2020 shows suddes decline in transaction.**
# ### **`Business Meaning`**
# - **Overall transaction growth is stable and healthy.**
# - **Needs slight improvement on platform for more future growth and compete with technology.**
# ### **`Possible Reasons`**
# - **Sudden user growth at beginning directly aligned with sudden transaction growth.**
# - **after mid 2020, transaction frequency starts declining shows people are prefering frequent small amount of transaction.**
# - **Few people does large amount of transactions.**
